# %%
import numpy
ux_euler = numpy.empty(2)
print(ux_euler)
# Out:
# [ 0.  0.]

# %%
import numpy
time=0
for x in range(1,110,2):
    print("x=",x)
    for y in range(10,14,1):
        print("y=",y)
        print("x=",x,"y=",y)
        time=time+1
        print("time=",time)
# Out:
# x= 1
# y= 10
# x= 1 y= 10
# time= 1
# y= 11
# x= 1 y= 11
# time= 2
# y= 12
# x= 1 y= 12
# time= 3
# y= 13
# x= 1 y= 13
# time= 4
# x= 3
# y= 10
# x= 3 y= 10
# time= 5
# y= 11
# x= 3 y= 11
# time= 6
# y= 12
# x= 3 y= 12
# time= 7
# y= 13
# x= 3 y= 13
# time= 8
# x= 5
# y= 10
# x= 5 y= 10
# time= 9
# y= 11
# x= 5 y= 11
# time= 10
# y= 12
# x= 5 y= 12
# time= 11
# y= 13
# x= 5 y= 13
# time= 12
# x= 7
# y= 10
# x= 7 y= 10
# time= 13
# y= 11
# x= 7 y= 11
# time= 14
# y= 12
# x= 7 y= 12
# time= 15
# y= 13
# x= 7 y= 13
# time= 16
# x= 9
# y= 10
# x= 9 y= 10
# time= 17
# y= 11
# x= 9 y= 11
# time= 18
# y= 12
# x= 9 y= 12
# time= 19
# y= 13
# x= 9 y= 13
# time= 20
# x= 11
# y= 10
# x= 11 y= 10
# time= 21
# y= 11
# x= 11 y= 11
# time= 22
# y= 12
# x= 11 y= 12
# time= 23
# y= 13
# x= 11 y= 13
# time= 24
# x= 13
# y= 10
# x= 13 y= 10
# time= 25
# y= 11
# x= 13 y= 11
# time= 26
# y= 12
# x= 13 y= 12
# time= 27
# y= 13
# x= 13 y= 13
# time= 28
# x= 15
# y= 10
# x= 15 y= 10
# time= 29
# y= 11
# ...

# %%
times=0 # account times
for theta in range(-0.1,0.4,2):
    for v0 in range(6.5,7.5,2): 
        times=times+1 # account times
        
ux_euler = numpy.empty(times)
print(ux_euler)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-0a70c966e515> in <module>()
#       1 times=0 # account times
# ----> 2 for theta in range(-0.1,0.4,2):
#       3     for v0 in range(6.5,7.5,2):
#       4         times=times+1 # account times
#       5
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
a=[1,2,3,7,8]
print(a.index(7)+1)
# Out:
# 4
